# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
rd=pd.read_csv("BL-Flickr-Images-Book.csv") # get csv file into pandas data frame

# %%
d=["Edition Statement", "Corporate Author", "Corporate Contributors", "Former owner", "Engraver"] # lots of column to delete that why made a list of all

# %%
rd.head(3)
# Out:
#    Identifier Edition Statement      Place of Publication Date of Publication  \
# 0         206               NaN                    London         1879 [1878]
# 1         216               NaN  London; Virtue & Yorston                1868
# 2         218               NaN                    London                1869
#
#                Publisher                                              Title  \
# 0       S. Tinsley & Co.                  Walter Forbes. [A novel.] By A. A
# 1           Virtue & Co.  All for Greed. [A novel. The dedication signed...
# 2  Bradbury, Evans & Co.  Love the Avenger. By the author of “All for Gr...
#
#       Author                                  Contributors  Corporate Author  \
# 0      A. A.                               FORBES, Walter.               NaN
# 1  A., A. A.  BLAZE DE BURY, Marie Pauline Rose - Baroness               NaN
# 2  A., A. A.  BLAZE DE BURY, Marie Pauline Rose - Baroness               NaN
#
# ...

# %%
rd.drop(d, inplace=True, axis=1) # delete all irralavent and unwanted columns and aplly direct to data frame

# %%
rd.head(3)
# Out:
#    Identifier      Place of Publication Date of Publication  \
# 0         206                    London         1879 [1878]
# 1         216  London; Virtue & Yorston                1868
# 2         218                    London                1869
#
#                Publisher                                              Title  \
# 0       S. Tinsley & Co.                  Walter Forbes. [A novel.] By A. A
# 1           Virtue & Co.  All for Greed. [A novel. The dedication signed...
# 2  Bradbury, Evans & Co.  Love the Avenger. By the author of “All for Gr...
#
#       Author                                  Contributors Issuance type  \
# 0      A. A.                               FORBES, Walter.   monographic
# 1  A., A. A.  BLAZE DE BURY, Marie Pauline Rose - Baroness   monographic
# 2  A., A. A.  BLAZE DE BURY, Marie Pauline Rose - Baroness   monographic
#
#                                           Flickr URL  \
# 0  http://www.flickr.com/photos/britishlibrary/ta...
# ...

# %%
rd["Identifier"].is_unique  #check whether Identifier is unique or not
# Out:
# True

# %%
rd.set_index("Identifier", inplace=True) # i made Identifier as Index

# %%
rd.head(3)
# Out:
#                 Place of Publication Date of Publication  \
# Identifier
# 206                           London         1879 [1878]
# 216         London; Virtue & Yorston                1868
# 218                           London                1869
#
#                         Publisher  \
# Identifier
# 206              S. Tinsley & Co.
# 216                  Virtue & Co.
# 218         Bradbury, Evans & Co.
#
#                                                         Title     Author  \
# Identifier
# 206                         Walter Forbes. [A novel.] By A. A      A. A.
# 216         All for Greed. [A novel. The dedication signed...  A., A. A.
# 218         Love the Avenger. By the author of “All for Gr...  A., A. A.
#
#                                             Contributors Issuance type  \
# Identifier
# 206                                      FORBES, Walter.   monographic
# 216         BLAZE DE BURY, Marie Pauline Rose - Baroness   monographic
# ...

# %%
rd.loc[218] #details regarding identifier number 218
# Out:
# Place of Publication                                               London
# Date of Publication                                                  1869
# Publisher                                           Bradbury, Evans & Co.
# Title                   Love the Avenger. By the author of “All for Gr...
# Author                                                          A., A. A.
# Contributors                 BLAZE DE BURY, Marie Pauline Rose - Baroness
# Issuance type                                                 monographic
# Flickr URL              http://www.flickr.com/photos/britishlibrary/ta...
# Shelfmarks                              British Library HMNTS 12625.dd.1.
# Name: 218, dtype: object

# %%
rd1=rd["Date of Publication"].str.extract(r'^(\d{4})') #removed extra dirt and clean the column "Date of Publication"

# %%
rd["Date of Publication"]=rd1

# %%
rd.head(3)
# Out:
#                 Place of Publication Date of Publication  \
# Identifier
# 206                           London                1879
# 216         London; Virtue & Yorston                1868
# 218                           London                1869
#
#                         Publisher  \
# Identifier
# 206              S. Tinsley & Co.
# 216                  Virtue & Co.
# 218         Bradbury, Evans & Co.
#
#                                                         Title     Author  \
# Identifier
# 206                         Walter Forbes. [A novel.] By A. A      A. A.
# 216         All for Greed. [A novel. The dedication signed...  A., A. A.
# 218         Love the Avenger. By the author of “All for Gr...  A., A. A.
#
#                                             Contributors Issuance type  \
# Identifier
# 206                                      FORBES, Walter.   monographic
# 216         BLAZE DE BURY, Marie Pauline Rose - Baroness   monographic
# ...

# %%
rd.loc[216] #now its look like bit cleaned
# Out:
# Place of Publication                             London; Virtue & Yorston
# Date of Publication                                                  1868
# Publisher                                                    Virtue & Co.
# Title                   All for Greed. [A novel. The dedication signed...
# Author                                                          A., A. A.
# Contributors                 BLAZE DE BURY, Marie Pauline Rose - Baroness
# Issuance type                                                 monographic
# Flickr URL              http://www.flickr.com/photos/britishlibrary/ta...
# Shelfmarks                              British Library HMNTS 12626.cc.2.
# Name: 216, dtype: object

# %%
rd.to_csv("Library_book_info_partially_cleaned.csv") # saved in csv file
