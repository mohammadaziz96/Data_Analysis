# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("cancer_b.csv")
df.head()
# Out:
#          Id Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# 0   8510426         B         13.540           14.36             87.46
# 1   8510653         B         13.080           15.71             85.63
# 2   8510824         B          9.504           12.44             60.34
# 3    854941         B         13.030           18.42             82.61
# 4  85713702         B          8.196           16.84             51.71
#
#    Area (mean)  Smoothness (mean)  Compactness (mean)  Concavity (mean)  \
# 0        566.3            0.09779             0.08129           0.06664
# 1        520.0            0.10750             0.12700           0.04568
# 2        273.9            0.10240             0.06492           0.02956
# 3        523.8            0.08983             0.03766           0.02562
# 4        201.9            0.08600             0.05943           0.01588
#
#    Concave points (mean)  ...  Radius (worst)  Texture (worst)  \
# ...

# %%
df.set_index("Id", inplace=True)

# %%
df.head()
# Out:
#          Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# Id
# 8510426          B         13.540           14.36             87.46
# 8510653          B         13.080           15.71             85.63
# 8510824          B          9.504           12.44             60.34
# 854941           B         13.030           18.42             82.61
# 85713702         B          8.196           16.84             51.71
#
#           Area (mean)  Smoothness (mean)  Compactness (mean)  \
# Id
# 8510426         566.3            0.09779             0.08129
# 8510653         520.0            0.10750             0.12700
# 8510824         273.9            0.10240             0.06492
# 854941          523.8            0.08983             0.03766
# 85713702        201.9            0.08600             0.05943
#
#           Concavity (mean)  Concave points (mean)  Symmetry (mean)  ...  \
# Id                                                                  ...
# ...

# %%
df.isna().any()
# Out:
# Diagnosis                    False
# Radius (mean)                False
# Texture (mean)               False
# Perimeter (mean)             False
# Area (mean)                  False
# Smoothness (mean)            False
# Compactness (mean)           False
# Concavity (mean)             False
# Concave points (mean)        False
# Symmetry (mean)              False
# Fractal dimension (mean)     False
# Radius (se)                  False
# Texture (se)                 False
# Perimeter (se)               False
# Area (se)                    False
# Smoothness (se)              False
# Compactness (se)             False
# Concavity (se)               False
# Concave points (se)          False
# Symmetry (se)                False
# Fractal dimension (se)       False
# Radius (worst)               False
# Texture (worst)              False
# Perimeter (worst)            False
# Area (worst)                 False
# Smoothness (worst)           False
# Compactness (worst)          False
# ...

# %%
df.isnull().any()
# Out:
# Diagnosis                    False
# Radius (mean)                False
# Texture (mean)               False
# Perimeter (mean)             False
# Area (mean)                  False
# Smoothness (mean)            False
# Compactness (mean)           False
# Concavity (mean)             False
# Concave points (mean)        False
# Symmetry (mean)              False
# Fractal dimension (mean)     False
# Radius (se)                  False
# Texture (se)                 False
# Perimeter (se)               False
# Area (se)                    False
# Smoothness (se)              False
# Compactness (se)             False
# Concavity (se)               False
# Concave points (se)          False
# Symmetry (se)                False
# Fractal dimension (se)       False
# Radius (worst)               False
# Texture (worst)              False
# Perimeter (worst)            False
# Area (worst)                 False
# Smoothness (worst)           False
# Compactness (worst)          False
# ...

# %%
N_features=df.select_dtypes(include=[np.number])
N_features.head()
# Out:
#           Radius (mean)  Texture (mean)  Perimeter (mean)  Area (mean)  \
# Id
# 8510426          13.540           14.36             87.46        566.3
# 8510653          13.080           15.71             85.63        520.0
# 8510824           9.504           12.44             60.34        273.9
# 854941           13.030           18.42             82.61        523.8
# 85713702          8.196           16.84             51.71        201.9
#
#           Smoothness (mean)  Compactness (mean)  Concavity (mean)  \
# Id
# 8510426             0.09779             0.08129           0.06664
# 8510653             0.10750             0.12700           0.04568
# 8510824             0.10240             0.06492           0.02956
# 854941              0.08983             0.03766           0.02562
# 85713702            0.08600             0.05943           0.01588
#
#           Concave points (mean)  Symmetry (mean)  Fractal dimension (mean)  \
# Id
# ...

# %%
C_features=df.select_dtypes(include=[np.object])
C_features.head()
# Out:
#          Diagnosis
# Id
# 8510426          B
# 8510653          B
# 8510824          B
# 854941           B
# 85713702         B

# %%
corr_data=N_features.corr()
a=plt.subplots(figsize=(30, 15))
a=sns.heatmap(corr_data, annot=True)
plt.show()

# %%
##it can be seen clearly which features are strongly corelated. for eg. Area(mean) is strongly corelated
##with radius(mean), peremeter(mean) and so on.
